# %%
#!/usr/bin/python3
"""Routine to load MasterDictionary class"""
# BDM : 201510

import time
import os
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig
from transformers import AutoTokenizer, AutoModelForSequenceClassification


### This is From Loughran Mcdonald, it loads the master dictionary file
def load_masterdictionary(file_path, print_flag=False, f_log=None, get_other=False):
    _master_dictionary = {}
    _sentiment_categories = ['negative', 'positive', 'uncertainty', 'litigious', 'constraining',
                             'strong_modal', 'weak_modal'] 
    # Load slightly modified nltk stopwords.  I do not use nltk import to avoid versioning errors.
    # Dropped from nltk: A, I, S, T, DON, WILL, AGAINST
    # Added: AMONG,
    _stopwords = ['ME', 'MY', 'MYSELF', 'WE', 'OUR', 'OURS', 'OURSELVES', 'YOU', 'YOUR', 'YOURS',
                       'YOURSELF', 'YOURSELVES', 'HE', 'HIM', 'HIS', 'HIMSELF', 'SHE', 'HER', 'HERS', 'HERSELF',
                       'IT', 'ITS', 'ITSELF', 'THEY', 'THEM', 'THEIR', 'THEIRS', 'THEMSELVES', 'WHAT', 'WHICH',
                       'WHO', 'WHOM', 'THIS', 'THAT', 'THESE', 'THOSE', 'AM', 'IS', 'ARE', 'WAS', 'WERE', 'BE',
                       'BEEN', 'BEING', 'HAVE', 'HAS', 'HAD', 'HAVING', 'DO', 'DOES', 'DID', 'DOING', 'AN',
                       'THE', 'AND', 'BUT', 'IF', 'OR', 'BECAUSE', 'AS', 'UNTIL', 'WHILE', 'OF', 'AT', 'BY',
                       'FOR', 'WITH', 'ABOUT', 'BETWEEN', 'INTO', 'THROUGH', 'DURING', 'BEFORE',
                       'AFTER', 'ABOVE', 'BELOW', 'TO', 'FROM', 'UP', 'DOWN', 'IN', 'OUT', 'ON', 'OFF', 'OVER',
                       'UNDER', 'AGAIN', 'FURTHER', 'THEN', 'ONCE', 'HERE', 'THERE', 'WHEN', 'WHERE', 'WHY',
                       'HOW', 'ALL', 'ANY', 'BOTH', 'EACH', 'FEW', 'MORE', 'MOST', 'OTHER', 'SOME', 'SUCH',
                       'NO', 'NOR', 'NOT', 'ONLY', 'OWN', 'SAME', 'SO', 'THAN', 'TOO', 'VERY', 'CAN',
                       'JUST', 'SHOULD', 'NOW']
    ## Read file
    with open(file_path) as f:
        _total_documents = 0 ##update total no of documents
        _md_header = f.readline()
        for line in f:
            cols = line.split(',') ##split by comma
            _master_dictionary[cols[0]] = MasterDictionary(cols, _stopwords)
            _total_documents += _master_dictionary[cols[0]].doc_count
            if len(_master_dictionary) % 5000 == 0 and print_flag:
                print('\r ...Loading Master Dictionary' + ' {}'.format(len(_master_dictionary)), end='', flush=True)

    if print_flag:
        print('\r', end='')  # clear line
        print('\nMaster Dictionary loaded from file: \n  ' + file_path)
        print('  {0:,} words loaded in master_dictionary.'.format(len(_master_dictionary)) + '\n')

    if f_log:
        try:
            f_log.write('\n\n  load_masterdictionary log:')
            f_log.write('\n    Master Dictionary loaded from file: \n       ' + file_path)
            f_log.write('\n    {0:,} words loaded in master_dictionary.\n'.format(len(_master_dictionary)))
        except Exception as e:
            print('Log file in load_masterdictionary is not available for writing')
            print('Error = {0}'.format(e))

    if get_other:
        return _master_dictionary, _md_header, _sentiment_categories, _stopwords, _total_documents
    else:
        return _master_dictionary


def create_sentimentdictionaries(_master_dictionary, _sentiment_categories): ##Create sentiment categories

    _sentiment_dictionary = {} ## dictionart for sentiments
    for category in _sentiment_categories:
        _sentiment_dictionary[category] = {}
    # Create dictionary of sentiment dictionaries with count set = 0
    for word in _master_dictionary.keys():
        for category in _sentiment_categories:
            if _master_dictionary[word].sentiment[category]:
                _sentiment_dictionary[category][word] = 0

    return _sentiment_dictionary

### Master Dicitonary class
class MasterDictionary:
    def __init__(self, cols, _stopwords):
        self.word = cols[0].upper()
        self.sequence_number = int(cols[1])
        self.word_count = int(cols[2])
        self.word_proportion = float(cols[3])
        self.average_proportion = float(cols[4])
        self.std_dev_prop = float(cols[5])
        self.doc_count = int(cols[6])
        self.negative = int(cols[7])
        self.positive = int(cols[8])
        self.uncertainty = int(cols[9])
        self.litigious = int(cols[10])
        self.constraining = int(cols[11])
        self.superfluous = int(cols[12])
        self.interesting = int(cols[13])
        self.modal_number = int(cols[14])
        self.strong_modal = False
        if int(cols[14]) == 1:
            self.strong_modal = True
        self.moderate_modal = False
        if int(cols[14]) == 2:
            self.moderate_modal = True
        self.weak_modal = False
        if int(cols[14]) == 3:
            self.weak_modal = True
        self.sentiment = {}
        self.sentiment['negative'] = bool(self.negative)
        self.sentiment['positive'] = bool(self.positive)
        self.sentiment['uncertainty'] = bool(self.uncertainty)
        self.sentiment['litigious'] = bool(self.litigious)
        self.sentiment['constraining'] = bool(self.constraining)
        self.sentiment['strong_modal'] = bool(self.strong_modal)
        self.sentiment['weak_modal'] = bool(self.weak_modal)
        self.irregular_verb = int(cols[15])
        self.harvard_iv = int(cols[16])
        self.syllables = int(cols[17])
        self.source = cols[18]

        if self.word in _stopwords:
            self.stopword = True
        else:
            self.stopword = False
        return

# %%
import csv
import glob
import re
import string
import sys
import time
import pandas as pd
import math

import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import os

# Load the tokenizer and model for FOMC-RoBERTa
tokenizer = AutoTokenizer.from_pretrained("gtfintechlab/FOMC-RoBERTa", do_lower_case=True, do_basic_tokenize=True)
# tokenizer = AutoTokenizer.from_pretrained("gtfintechlab/FOMC-RoBERTa", do_lower_case=True)
model = AutoModel.from_pretrained("gtfintechlab/FOMC-RoBERTa")

def get_embeddings(text, max_token_length=512):
    # Tokenize the document with truncation to the specified max_length
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=max_token_length)
    
    # Pass the tokenized input through the model
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state  # This gives the embeddings for each token
    
    # Pooling: Take the mean of the token embeddings to get a single vector representation
    pooled_embedding = embeddings.mean(dim=1).squeeze().numpy()
    
    return pooled_embedding

# Function to compute cosine similarity between two vectors
def compute_cosine_similarity(embedding1, embedding2):
    # Reshape the embeddings if necessary (sklearn expects 2D arrays)
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)
    
    return cosine_similarity(embedding1, embedding2)[0][0] ## Return cosine similarity between the two embeddings

# Extremely Hawkish Texts
hawkish_texts = [
    "Given the persistent inflationary pressures, the Federal Reserve will need to raise interest rates aggressively to curb rising prices and prevent the economy from overheating.",
    "We are committed to a sustained period of tightening, including several consecutive rate hikes, until inflation falls decisively back to our 2% target.",
    "Inflation is far too high, and we must take all necessary measures, including aggressive interest rate increases, to restore price stability.",
    "The current labor market is excessively tight, driving wage inflation, and we will continue to raise rates to ensure that inflationary pressures are contained.",
    "We are prepared to maintain a restrictive stance on monetary policy for an extended period, with further rate hikes expected in the coming months.",
    "Monetary tightening is necessary to reduce the risks of an overheating economy, and we will not hesitate to act decisively with higher rates to prevent runaway inflation.",
    "The risk of high inflation outweighs concerns about slowing economic growth. Rate hikes will continue until we are confident inflation is firmly under control.",
    "Given the strength of consumer demand and rising input costs, inflation remains a primary concern, and we will aggressively use rate hikes to cool down price pressures.",
    "We are unlikely to pivot toward accommodative policies anytime soon. Sustained interest rate hikes are necessary to restore price stability and anchor inflation expectations.",
    "With inflationary pressures proving more persistent than anticipated, the Federal Reserve will take preemptive actions to raise rates even higher, ensuring inflation does not become entrenched."
]

# Extremely Dovish Texts
dovish_texts = [
    "Given the risks of slowing economic growth, the Federal Reserve is prepared to maintain its accommodative stance and will keep interest rates low to support recovery and job creation.",
    "We believe that the current inflationary pressures are transitory, and therefore, it is crucial to avoid premature tightening that could derail economic growth.",
    "Our primary focus is on maximizing employment, and we are committed to keeping interest rates low until the labor market has fully recovered.",
    "In light of ongoing economic challenges, the Federal Reserve will continue to provide liquidity and maintain low rates to support the economy's sustained recovery.",
    "With unemployment still elevated in some sectors, we are committed to keeping monetary policy accommodative, ensuring that the recovery benefits all Americans.",
    "The current economic environment requires patience. The Federal Reserve will keep interest rates near zero for the foreseeable future to ensure continued growth and job creation.",
    "We see no need to raise interest rates in the near term. Our priority is supporting a full and inclusive recovery, especially for those still struggling in the labor market.",
    "To support economic activity, the Federal Reserve is committed to maintaining its low interest rate policy and using all available tools to stimulate demand.",
    "Given the uncertain global economic outlook, we are prepared to lower interest rates further or maintain them at current levels to prevent any slowdown in growth.",
    "We believe that accommodative monetary policy will be essential in supporting long-term economic growth, and therefore, rate hikes are not on the table in the near future."
] 

# Generate vector embeddings for the hawkish and dovish texts to compute cosine similarity
hawkish_embedding = get_embeddings(" ".join(hawkish_texts))
dovish_embedding = get_embeddings(" ".join(dovish_texts))


MASTER_DICTIONARY_FILE = '/Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/LoughranMcDonald_MasterDictionary_2018.csv'

lm_dictionary = load_masterdictionary(MASTER_DICTIONARY_FILE, True)
n_words=[] ## list of negative words

for word in lm_dictionary.keys(): ##if word in loughran mcd list is negative then append to list of negative words 
    if(lm_dictionary[word].negative):
        n_words.append(word)

df_neg = pd.DataFrame(columns=n_words) ## stores dataframe that has all neg words as columns and no of docs as rows
tot_words=[] ##stores total words in doc i
neg_words=[] ##stores neg words in doc i
dov_score=[] ##stores dovish cosine similarity of  doc i
hawk_score=[] ##stores hawkish cosine similarity of  doc i
files=[] ##stores name of file i

import os

common='/Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/'


folders = [f"{common}{'FOMC_Minutes'}", f"{common}{'FOMC_Press_Conference'}", f"{common}{'FOMC_Speech'}"]
### to iterrate over three data folders

# Initialize a dictionary to store the filenames for each folder
txt_files = []

for folder in folders:
    folder_path = os.path.join(common, folder)
    file_names = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.txt')]
    txt_files.append(file_names) ##append .txt files in all folder to a common list
    
txt_files=[item for sublist in txt_files for item in sublist] ##append .txt files in all folder to a common list

def main():
    global tot_words
    global neg_words
    global txt_files
    global files
    global dov_score
    global hawk_score
    for file in txt_files: ## read file one by one from txt_files
        print(file)
        with open(file, 'r', encoding='UTF-8', errors='ignore') as f_in:
            doc = f_in.read()
            
        file_embedding = get_embeddings(doc) ## get vector embedding for file i
        
        ## compute cosine similairty to hawkish anf dovish target 
        similarity_to_hawkish = compute_cosine_similarity(file_embedding, hawkish_embedding)
        similarity_to_dovish = compute_cosine_similarity(file_embedding, dovish_embedding)
        
        doc_len = len(doc)
        doc = re.sub('(May|MAY)', ' ', doc)  # drop all May month references
        doc = doc.upper()  # for this parse caps aren't informative so shift
        output_data = get_data(doc)
        output_data[0] = file
        output_data[1] = doc_len
        tot_words.append(output_data[2]) ##append total wordds
        neg_words.append(output_data[4]) ##append eng wordds
        dov_score.append(similarity_to_dovish) ##append dovish score wordds
        hawk_score.append(similarity_to_hawkish) ##append hawkish score
        file_name = file.split('/')[-1]
        files.append(file_name) ##append file name


### routine to iterate over document token by token
def get_data(doc):
    global df_neg
    global df_neg_h
    vdictionary = {}
    _odata = [0] * 17
    total_syllables = 0
    word_length = 0
    
    tokens = re.findall('\w+', doc)  # Note that \w+ splits hyphenated words
    
    word_counts = {word:0 for word in n_words}
    
    for token in tokens:
        if not token.isdigit() and len(token) > 1 and token in lm_dictionary:
            _odata[2] += 1  # word count
            word_length += len(token)
            if token not in vdictionary:
                vdictionary[token] = 1
            if lm_dictionary[token].negative: ## add to neg word if word is negative
                _odata[4] += 1
                word_counts[token]+=1 
                
    df_neg = pd.concat([df_neg, pd.DataFrame([word_counts])], ignore_index=True) ## append a row to dataframe

        
    return _odata


if __name__ == '__main__':
    print('\n' + time.strftime('%c') + '\nGeneric_Parser.py\n')
    main()
    print('\n' + time.strftime('%c') + '\nNormal termination.')



df_tf_idf=df_neg.copy() ##df to. calculate tf-idf score
df_i=[0]*df_neg.shape[1]

###COMPUTING TF-IDF using fromaula provided in the loughran mcdonald paper
for i in range(df_tf_idf.shape[0]):#docs
    for j in range(df_tf_idf.shape[1]):## words
        if(df_tf_idf.iloc[i,j]):
            df_tf_idf.iloc[i,j]=(1+math.log(df_tf_idf.iloc[i,j]))/(1+math.log(tot_words[i]))
            df_i[j]+=1

df_i=[math.log(df_tf_idf.shape[0]/i) if i else i for i in df_i]
df_tf_idf = df_tf_idf.mul(df_i, axis=1)

df_=df_tf_idf.copy()
df_['tfidf']=[sum(df_.iloc[i,:]) for i in range(df_.shape[0])]
df_['file_name']=files
df_['hawkish']=hawk_score
df_['dovish']=dov_score
df_=df_[['file_name','tfidf','hawkish','dovish']]
df_
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at gtfintechlab/FOMC-RoBERTa and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#  ...Loading Master Dictionary 85000
# Master Dictionary loaded from file:
#   /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/LoughranMcDonald_MasterDictionary_2018.csv
#   86,486 words loaded in master_dictionary.
#
#
# Sat Oct 12 17:44:33 2024
# Generic_Parser.py
#
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20131218.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20121023.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20181108.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20231101.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20161214.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20201216.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180613.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130501.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20171213.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210127.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160727.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200916.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20131030.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170726.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140430.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120313.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20221102.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20211215.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160127.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240501.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140618.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20151028.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20151216.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220126.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190501.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160427.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150917.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230726.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20191030.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140319.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240612.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20161102.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230322.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150318.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220727.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140917.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140730.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20231213.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20201105.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20221214.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180502.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180926.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20211103.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20171101.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20141029.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20181219.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20141217.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20191211.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120425.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200610.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150128.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120801.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180321.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190130.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210616.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170614.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210428.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230920.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220316.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150729.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220504.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160615.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200429.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220921.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170201.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130619.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180131.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120620.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20140129.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190731.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230503.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170503.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200129.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20180801.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210728.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130130.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230201.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240731.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200315.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160316.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20160921.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20220615.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170920.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210922.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20121212.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20230614.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20200729.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150617.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120125.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20150429.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20190619.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20240131.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20120913.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20170315.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20130731.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Minutes/FOMCminutes20210317.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240501.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20140618.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20211215.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20221102.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200916.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20130918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210127.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20171213.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20161214.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20201216.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20180613.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20131218.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20231101.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20180926.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20211103.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20181219.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20141217.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20221214.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20140917.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20231213.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20201105.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20150318.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220727.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20150917.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230726.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20191030.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20140319.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240612.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230322.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190501.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190918.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220126.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20151216.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190731.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230503.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20130619.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20120620.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220316.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220504.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20160615.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220921.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200429.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210616.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20170614.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230920.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210428.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190130.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200610.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20180321.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20191211.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20120425.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20120913.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20170315.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210317.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240131.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20130320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200729.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20150617.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20120125.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20190619.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20170920.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210922.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20121212.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230614.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20160316.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240320.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20160921.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20220615.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20210728.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20230201.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200315.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20240731.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200303.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Press_Conference/FOMCpresconf20200129.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190513a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20210628a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20220617a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230210a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230922a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20220928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190402a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20230928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230302a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240724a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20170404a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20211202a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240227a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20211019a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20191008a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20231010a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/kugler20240716a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170927a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240227a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20160621a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230713a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20220907a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20211013a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20210113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20181205a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20160226a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20170328a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20160210a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20200521a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190603a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20201204a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20150327a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120326a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20210803a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20130408a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20170420a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20181116a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20201015a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20231018a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20221020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20160103a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20151201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20161118a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20181004a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20131004a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20150624a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20200116a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20200409a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230420a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20240519a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20200109a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20150829a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240710a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20131014a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20121014a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200806a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20140415a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20240416a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230524a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20230404a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20131002a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/raskin20120723a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20210113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170301a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201217a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20191004a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20171020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20220524a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240614a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20180417a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20161117a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20190212a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20220806a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240207a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20170601a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20121128a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20130404a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20231128a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20120410a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20241011a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20160520a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20210805a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20171102a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20120502a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20211108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20130412a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20221201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190530a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20200819a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20231201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20150710a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20231106a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20160826a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20130926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20231026a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20231128a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20190625a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20160929a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170620a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20220909a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190927a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200714a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120413a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20220930a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20211018a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20151203a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240617a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20150928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20160414a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150218a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20230329a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20130503a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20200831a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20210623a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240528a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201001a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170117a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20171213a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230807a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20181207a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20231017a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20180213a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20171116a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20130419a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20200930a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20210112a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20180912a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150625a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20151002a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20210325a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20171012a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20160603a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20230106a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20150506a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150408a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20160821a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170711a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20210330a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20210108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20200221a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20240513a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20150330a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20191114a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/kugler20240404a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240709a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20140822a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170505a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230519a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20160606a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20150930a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/raskin20130606a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240924a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170417a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20201014a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20230518a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20141106a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120409a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20191101a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240709a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20220221a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240820a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20140508a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20161115a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170211a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20160329a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201021a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20230309a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20231108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20161202a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20190621a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170530a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20180927a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/duke20130509a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20191009a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20231109a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20170112a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20190508a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200221a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20230718a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230616a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20190823a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20230331a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20121130a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20220928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20140710a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20140501a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/kugler20240618a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240515a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/duke20120113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20211117a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20170328a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20180326a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20210225a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20151202a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20180515a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20220826a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20231108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20160307a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20170119a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20181002a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20121010a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20150709a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240503a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20180222a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20211019a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230314a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190222a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20131018a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20181017a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20231116a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20181018a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20130510a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20151105a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120510a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20210302a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150209a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20190201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150120a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20210601a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20181113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230512a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20181203a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240305a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20161202a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20160926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170627a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20141107a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20140321a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20220324a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/kugler20240301a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20180824a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20140331a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20161104a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230420a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20190520a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20180516a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20220405a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190411a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20210512a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190503a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20220318a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150803a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20150327a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240626a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20230227a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20131122a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20231201a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240718a.txt
# ...
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20211129a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20200227a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240521a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240401a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240710a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201110a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170905a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20220708a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20171012a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230208a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20180226a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20171115a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20231002a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20211130a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120216a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20161007a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20161219a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240624a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240403a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20201119a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240327a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20220530a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20190206a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20180403a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20231002a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20181025a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20180119a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20241010a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20151104a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20140103a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20120612a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240910a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20170713a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240510a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20120606a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20161021a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/duke20120116a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20151020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20141020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240402a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20151019a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20140416a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20190510a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20220618a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240117a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230215a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20121001a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20161009a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20160927a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20191007a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20231107a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20121113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20230119a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240117a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200813a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20230515a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20151112a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240617a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20131113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230120a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240222a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200901a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240910a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20211020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240510a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20201020a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230805a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20191021a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20190325a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230622a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20231113a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240520a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/duke20130205a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20190711a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20131216a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20211217a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20170706a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20161121a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201015a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/kugler20240518a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20181206a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20220321a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120807a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20210322a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240504a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190530a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20231025a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170419a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20120411a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20201019a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20160912a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20130104a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20230110a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/duke20121005a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20160622a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240212a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20171005a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20170825a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20200521a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20140324a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20231019a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20141030a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20210928a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20150514a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20191017a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/quarles20190905a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20180525a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/raskin20120106a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20211108a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240418a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20131011a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20201218a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20210517a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20191001a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/tarullo20141120a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20161005a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/clarida20190228a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20130417a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20120831a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/fischer20170706a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20130325a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20121011a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20150924a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200921a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240828a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/barr20240926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240930a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bernanke20131216b.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/stein20130207a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20240717a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20200521a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/jefferson20241009a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/cook20240508a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20160226a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20240926a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20171015a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/bowman20190411a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20221010a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/brainard20141202a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20180620a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/waller20230511a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/powell20190509a.txt
# /Users/devanshjoshi/tensorflow-test/NLP- Dan Rodriguez/Assignment_2/Data/FOMC_Speech/yellen20171107a.txt
#
# Sat Oct 12 18:06:05 2024
# Normal termination.
#                    file_name      tfidf   hawkish    dovish
# 0    FOMCminutes20131218.txt  20.529626  0.130615  0.537401
# 1    FOMCminutes20121023.txt  16.736768  0.137413  0.547877
# 2    FOMCminutes20181108.txt  13.417258  0.137908  0.538247
# 3    FOMCminutes20231101.txt  14.167732  0.135363  0.535311
# 4    FOMCminutes20161214.txt  12.337477  0.137458  0.539062
# ..                       ...        ...       ...       ...
# 912    brainard20141202a.txt   4.514435  0.159401  0.535447
# 913      powell20180620a.txt   8.119419  0.319314  0.644812
# 914      waller20230511a.txt  17.852031  0.136195  0.521566
# 915      powell20190509a.txt   2.168036  0.158238  0.548112
# 916      yellen20171107a.txt   8.237445  0.135761  0.524598
#
# [917 rows x 4 columns]

# %%
df_.to_csv('df_hawk-dov-tfidf')
